# %% [markdown]
# # Image reconstruction in X-ray tomography
# * Authors: Mengda Li, Ségolène Martin

# %% [markdown]
# ## 1. X-ray tomography
#
# The measurements $y \in R^M$ and the sought absorption image $\bar{x} \in R^N$ obey the linear relation:
# $$y = H \bar{x} + w\tag{1}$$
# where $w ∈ R^M$ is the measurement noise, that we assume i.i.d. Gaussian with variance $σ^2$. The tomography matrix $H ∈R^{M×N}$ is sparse and encodes the geometry of the measurements.

# %% [markdown]
# 1. Download the projection matrix $H$ and the image $\bar{x}$ available on the website. Use `loadmat` from `scipy.io` in Python to load the arrays, note that $H$ is stored as a sparse matrix.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
from pathlib import Path
from scipy.sparse import csr_matrix
from scipy.linalg import norm
import time

p = Path('data')
MATRICES = dict()
for matrix in p.iterdir():
    matrix_name = matrix.name[0]
    MATRICES[matrix_name] = sio.loadmat(matrix)

H = MATRICES['H']['H']
x = MATRICES['x']['x']
M, N = H.shape

H = csr_matrix(H)
x = x.reshape(N)

# %% [markdown]
# 2. Construct $y$, according to model (1), using $σ = 1$.

# %%
# sigma = 1
w = np.random.normal(size = M)
y = H @ x + w

# %% [markdown]
# 3. Here, $N = 90×90$ pixels and $M = 90×180$ measurements. Display a 2D version of $x$ and a 2D version of $y$, also known as sinogram.

# %%
# plt.figure(figsize = (27,9))
plt.rcParams["figure.figsize"] = (27,9)
_, (a0, a1) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [1, 2]})
a0.imshow(np.reshape(x, (90, 90)))
a0.set_title('x')
a1.imshow(np.reshape(y, (90, 180)))
a1.set_title('y');

# %% [markdown]
# ## 2. Optimization problem

# %% [markdown]
# An eﬃcient strategy to address the reconstruction problem is to deﬁne $x $as a minimizer of an appropriate cost function $f$. More speciﬁcally, we focus on the following penalized least-squares criterion :
# $$\forall x  ∈R^N, \ f(x) =
# \frac{1}{2}∥Hx−y∥^2 + λr(x) \tag{2} $$

# %% [markdown]
# where $r$ is a regularization function incorporating a priori assumptions to guarantee the robustness of the solution with respect to noise. In order to promote images formed by smooth regions separated by sharp edges, we set
# $$∀x ∈R^N, \ r(x) =
#  ∑^{2N}_{n=1}
# ψ([Gx]^{(n)}) \tag{3}
# $$

# %% [markdown]
# where $G ∈R^{2N×N}$ is a sparse matrix such that $Gx ∈R^{2N}$ is the concatenation of the horizontal and vertical gradients of the image, and $ψ$ is a potential function deﬁned as :
# $$∀u ∈R, \ ψ(u) =\sqrt{1 + u^2/δ^2}  \tag{4}$$
# with some parameter $δ > 0$ aiming at guaranteeing the diﬀerentiability of $r$. In the following, we will set $(λ,δ) = (0.13,0.02)$.

# %% [markdown]
# 1. Download the gradient operator $G$ available in the website.

# %%
G = MATRICES['G']['G']
G = csr_matrix(G)

# %% [markdown]
# 2. Give the expression of the gradient $∇f$ at some point $x ∈ R^N$. Create a function which gives as an output the gradient of $f$ at some input vector $x$.

# %% [markdown]
# <!-- In fact, the gradient $\nabla f$ here is the jacobian of $f$. -->
# $$\nabla{f}(x) = H^TH x - H^Ty + \lambda \nabla{r}(x)$$
# Let ${(e_n)_{n \in [1 .. 2N]}}$ be the canonical vector basis in $\mathbb{R}^{2N}$,
#
# <!-- $$
# \begin{aligned}
#  AR(p): Y_i &= c + \epsilon_i + \phi_i Y_{i-1} \dots \\
#  Y_{i} &= c + \phi_i Y_{i-1} \dots
# \end{aligned}
# $$
# $$\nabla r(x)^T = \sum_{n = 1}^{2N} \psi'(e_n^T G x) e_n^T G $$ -->
#
# $$
# \begin{aligned}
# r(x) &= \sum_{n = 1}^{2N} \psi(e_n^T G x) \\
# \nabla r(x)^T &= \sum_{n = 1}^{2N} \psi'(e_n^T G x) e_n^T G
# \end{aligned}
# $$
# where $\psi'(u) = \frac{u}{\delta^2 \sqrt{1+\frac{u^2}{\delta^2} }}$.
#
# so $$\nabla{f}(x)^T = x^T H^TH - y^TH +
# \lambda \sum_{n = 1}^{2N}\frac{e_n^T G x}{\delta^2 \sqrt{1+\frac{(e_n^T G x)^2}{\delta^2} }} e_n^T G $$
# $$
# \nabla{f}(x) = H^TH x - H^Ty +
# \lambda \sum_{n = 1}^{2N}\frac{[G x]^{(n)}}{\delta^2 \sqrt{1+\frac{([G x]^{(n)})^2}{\delta^2} }} [G]^{(n)}
# $$
# where $[G]^{(n)}$ is the vector of the $n$-th row of $G$.

# %%
LAMBDA, DELTA = 0.13, 0.02
DELTA2 = DELTA**2
Hy = H.T @ y
HH = H.T @ H

def grad_f(x):
    def grad_r(x):
        def dev_psi(u: np.array):
            return u / (DELTA2 * np.sqrt(1 + u**2 / DELTA2))
        Gx = G @ x
#         vec =  Gx / (DELTA2 * np.sqrt(1 + Gx**2 / DELTA2))
        return G.T @ dev_psi(Gx) #dev_psi(Gx).T * G
#     return HH * x - Hy + LAMBDA * grad_r(x)
    return H.T @ (H @ x) - Hy + LAMBDA * grad_r(x)

# %% [markdown]
# 3. Show that a Lipschitz constant of $∇f$ is
# $$L = ∥H∥^2 + (\lambda / \delta^2) ∥G∥^2$$
# Calculate it for the $(\lambda, \delta^2)$ values given above. Note that,  in Python, the function
# `scipy.sparse.linalg.svds` gives the singular values of a sparse matrix, the
# maximal singular value being the norm of the matrix.

# %% [markdown]
# $\newcommand{\norm}[1]{\left\lVert#1\right\rVert}$
# Let $R(x,x') = \lambda \norm{\nabla r(x) - \nabla r(x')}$,
# $$
# \begin{aligned}
# \forall x, x' \in \mathbb{R}^N, \
# \norm{ \nabla f(x) - \nabla f(x')} &\leq \norm{H^TH (x-x')} + R(x,x') \\
# & \leq \norm{H^TH} \norm{(x-x')}+ R(x,x') \\
# & \leq \norm{H^T}\norm{H}\norm{(x-x')} + R(x,x') \\
# & = \norm{H}^2\norm{(x-x')} + R(x,x')
# \end{aligned}
# $$
# For the last equality, $H$ and $H^T$ have the same euclidean norm because they have the same singular values. The largest singular value is the euclidean matrix norm.

# %% [markdown]
# It remains to give an upper bound on $R(x,x')$, so let us find an upper bound of $\nabla^2 r(x)$:
# $$
# \begin{aligned}
# \forall x \in \mathbb{R}^N, \
# \nabla^2r(x) &= \sum_{n=1}^{2N} G^T e_n \psi''(e_n^T Gx)e_n^T G \\
#             &= G^T \texttt{diag}\left(\psi''([Gx]^{(n)}) \right)G
# \end{aligned}
# $$
# Because $\sum_{n=1}^{2N} e_n e_n^T = Id$.
#
# Then we need to majorize $\psi''([Gx]^{(n)})$ where $\psi''(u) = \frac{1}{\sqrt{\frac{u^2}{δ^2} + 1} \left(δ^2 + u^2 \right)}$.
#
# It is clear that $$\psi''(x) \leq \omega(x) \quad \forall x \in \mathbb{R}$$
#
# where $\omega(x) = \frac{1}{\delta^2 \sqrt{1+\frac{x^2}{\delta^2}}}$
#
# So $$
# \begin{aligned}
# \forall x \in \mathbb{R}^N, \
# \nabla^2r(x) &= G^T \texttt{diag}\left(\psi''([Gx]^{(n)}) \right)G \\
# &\leq G^T \Delta \left(Gx \right)G
# \end{aligned}
# $$
# where $\Delta(x) = \text{diag}\left( \omega(x_i)_{i \in [1..N]}\right) =   \begin{bmatrix}
#     \frac{1}{\delta^2 \sqrt{1+\frac{x_1^2}{\delta^2} }}  & & \\
#     & \ddots & \\
#     & & \frac{1}{\delta^2 \sqrt{1+\frac{x_N^2}{\delta^2} }}
#   \end{bmatrix}$

# %% [markdown]
# Fortunately, $\max_x \frac{1}{\delta^2 \sqrt{1+\frac{x^2}{\delta^2} }} = \frac{1}{\delta^2}$ with $\arg\max = 0$. So $\Delta(x) \preceq \frac{1}{\delta^2} Id$.
#
# Finally, we proved $\nabla^2 r(x) \preceq \frac{1}{\delta^2} G^T G, \quad \forall x\in \mathbb{R}^N$ which implies the following descent lemma on $r$:
# $$
# \begin{aligned}
# \forall x\in \mathbb{R}^N, \
# (∀y ∈ \mathbb{R}^N) \quad r(y) &\le r(x) + \langle y − x | ∇r(x) \rangle + \frac{1}{2\delta^2}(x − y)^T G^TG(x − y)\\
#  &\le r(x) + \langle y − x | ∇r(x) \rangle + \frac{1}{2\delta^2}\|G\|^2 (x − y)^T (x − y)
# \end{aligned}
# $$
# where $\|G\|^2$ is the largest absolute eignvalue of $G^TG$.
#
# This descent lemma implies that $\nabla r$ is $\frac{\|G\|^2}{\delta^2}$-Lipschitz continuous which means $\nabla f$ is $(\|H\|^2 + \frac{\lambda}{\delta^2}\|G\|^2)$-Lipschitz continuous.

# %%
from scipy.sparse.linalg import svds
L = ( svds(H, k = 1)[1] + (LAMBDA/DELTA2) * svds(G, k = 1)[1] )[0]

# %% [markdown]
# ## 3. Optimization algorithms

# %% [markdown]
# ### 3.1 Gradient descent algorithm

# %% [markdown]
# 1. Create $x_0 \in R^N$ a vector with all entries equal to $0$. This will be our initialization for all tested algorithms.

# %%
x_0 = np.zeros(N)

# %% [markdown]
# 2. Implement a gradient descent algorithm to minimize $f$.

# %% [markdown]
# Note that $\psi''(u) > 0$ so $f$ is convex.

# %%
def line_search(f,
                x: "starting point in the feasible domain of f",
                Delta_x: "descent direction",
                gradient_f_x: "gradient of f at x",
                initial_step = 2/L,
                a = 0.25,
                b=0.5
#                 Steps = np.array([1e-1, 0.25, 0.5, 0.75, 0.99]) * 2/L
    ) -> "step size":
    """Backtracking line search."""
#     Candidate_values = np.array([f(x + t*Delta_x) for t in Steps])
#     return Steps[np.argmin(Candidate_values)]
    t = initial_step
    while f(x + t*Delta_x) > f(x) + a*t*gradient_f_x @ Delta_x:
        t = b*t
    return t

def grad_descent(
        f: "convex function to be minimized",
        gradient_f: "function to compute the gradient of f at some point x",
        x: "starting point in the strictly feasible domain of f",
        e: "tolerance, >0",
    list_values = False ) -> "argmin f":
    """Gradient descent method."""
    
    counter = 0
    v = []
    start_time = time.time()
    
    while True:
        Grad_f_x = gradient_f(x)
        criterion = norm(Grad_f_x)
        if criterion < e:
            temps = time.time() - start_time
            print("{} iterations, gradient norm is {}, elapsed time {:f}".format(counter, criterion, temps))
            if list_values == True:
                return [v, temps]
            else :
                return x

        search_direction =  -Grad_f_x 
        
        t = line_search(f, x, search_direction, Grad_f_x)
        x = x + t*search_direction
        if list_values == True:
                v.append(f(x))
        
        counter+=1
        if counter%100 == 0:
            print("{} iterations, gradient norm is {}, elapsed time {:f}".format(counter, criterion, time.time() - start_time))

# %%
yy = y @ y
def f(x):
    def r(x):
        def psi(u: np.array):
            return np.sqrt(1 + u**2/DELTA2)
        Gx = G @ x
        return np.sum(psi(Gx))
    Hx = H @ x
    return 1/2 * (Hx @ Hx -2* x@Hy + yy) + LAMBDA * r(x)
    
TOLERANCE = np.sqrt(N) * 1e-4

# %%
optimum_gd = grad_descent(f, grad_f, x_0, TOLERANCE)
# Out:
# 100 iterations, gradient norm is 13.566078395961254, elapsed time 4.475609
# 200 iterations, gradient norm is 2.602730612240829, elapsed time 9.233105
# 300 iterations, gradient norm is 1.5072307528841367, elapsed time 13.891685
# 400 iterations, gradient norm is 0.0773996207931491, elapsed time 18.804998
# 500 iterations, gradient norm is 0.11341735226520352, elapsed time 24.437240
# 600 iterations, gradient norm is 0.015056107909622685, elapsed time 28.861518
# 607 iteraions, gradient norm is 0.008014473590000824, elapsed time 29.230328

# %% [markdown]
# ### 3.2 MM quadratic algorithm

# %% [markdown]
# 1. Construct, for all $x \in R^N$, a quadratic majorant function of $f$ at $x$. Create
# a function which gives, as an output, the curvature $A(x)$ of the majorant
# function at an input vector $x$.
#
# Hint :  in Python,
# use `scipy.sparse.diags(d[:,0]).tocsc()` to create a sparse matrix from a
# diagonal vector $d \in R^{n \times 1}$ using the compressed sparse column format. In addition, in Python, use the class `LinearOperator` from `scipy.sparse.linalg`
# to create the curvature operator.

# %% [markdown]
# <!-- I proved the curvature $A(x)$ of majorization in the question.   -->
# From the answer of the question`2.3`:
# $$
# \begin{aligned}
# \forall x \in \mathbb{R}^N, \
# \nabla^2r(x) &= G^T \text{diag}\left(\psi''([Gx]^{(n)}) \right)G \\
# &\leq G^T \Delta \left(Gx \right)G
# \end{aligned}
# $$
# where $\Delta(x) = \text{diag}\left( \omega(x_i)_{i \in [1..N]}\right) =   \begin{bmatrix}
#     \frac{1}{\delta^2 \sqrt{1+\frac{x_1^2}{\delta^2} }}  & & \\
#     & \ddots & \\
#     & & \frac{1}{\delta^2 \sqrt{1+\frac{x_N^2}{\delta^2} }}
#   \end{bmatrix}$
#
# So $$
# \begin{aligned}
# \forall x \in \mathbb{R}^N, \
# \nabla^2 f(x) &= H^TH + \nabla^2r(x) \\
#                 &\leq \underbrace{H^TH + G^T \Delta \left(Gx \right)G}_{A(x)}
# \end{aligned}
# $$
# We can hence build a quadratic majorization function $h$ of $f$ by setting
# $$(∀x ∈ \mathbb{R}^N) \ h(x, y) = f (y) + \langle ∇f (y)|x − y \rangle+
# \frac{1}{2}\lVert x − y \rVert^2
# _{A(y)}
# $$
# For all $y\in R^N$, we have $∀x ∈ \mathbb{R}^N, \ h(x, y) \ge f(x)$

# %%
from scipy.sparse import diags
from scipy.sparse.linalg import LinearOperator
from functools import partial

def A(x):
    def Delta(u: np.array):
        def dev_psi_over_u(u: np.array):
            return 1 / (DELTA2 * np.sqrt(1 + u**2 / DELTA2))
#         flatten = (dev_psi_div_u(u)).reshape(2*N)
        return diags(dev_psi_over_u(u))
    Gx = G @ x
    def Ax_u(Gx, u):
        return H.T @ (H @ u) + LAMBDA * G.T @ (Delta(Gx) @ (G @ u))
    matvec = partial(Ax_u, Gx)
    
    return LinearOperator((N, N), matvec = matvec, rmatvec = matvec)

# %% [markdown]
# 2. Deduce a MM quadratic algorithm to minimize $f$. Implement it.
#
# Hint : in
# Python, use `bicg` from `scipy.sparse.linalg`.

# %%
from scipy.sparse.linalg import bicg

def MM(f = f,
       gradient_f = grad_f, 
    x_0 = x_0,
      TOLERANCE = TOLERANCE,
      list_values = False ):
    
    x = x_0
    v = []
    counter = 0
    start_time = time.time()
    while True:
        Grad_f_x = gradient_f(x)
        criterion = norm(Grad_f_x)
        if criterion < TOLERANCE:
            temps = time.time() - start_time
            print("{} iterations, gradient norm is {}, elapsed time {:f}".format(counter, criterion, temps))
            if list_values == True:
                return [v, temps]
            else :
                return x

        search_direction =  -bicg(A(x), Grad_f_x)[0] 
        
        t = line_search(f, x, search_direction, Grad_f_x, initial_step=2)
        x = x + t*search_direction
        if list_values == True:
                v.append(f(x))

        counter+=1
        #print("{} iterations, gradient norm is {}, elapsed time {:f}".format(counter, criterion, time.time() - start_time))    
        
        if counter%100 == 0:
            print("{} iterations, gradient norm is {}, elapsed time {:f}".format(counter, criterion, time.time() - start_time))

# %%
optimum_MM = MM()
# Out:
# 39 iterations, gradient norm is 0.008279219977985296, elapsed time 21.457356

# %% [markdown]
# _Remark_: The relative error between the optimums obtained by 2 different algorithms is relatively small:

# %%
np.max(np.abs(optimum_MM- optimum_gd))
# Out:
# 0.00012797131432584763

# %% [markdown]
# ### 3.3 3MG algorithm

# %% [markdown]
# 1. Implement the 3MG algorithm.
#
# Hint : use `scipy.linalg.pinv` in Python to compute the
# pseudo-inverse. Given the size of the matrices, mind the order of matrix multiplications, e.g. when computing
# $D_k^⊤  H^⊤HD_k$ do not compute
# $D_k^⊤(H^⊤H)D_k$
# but $(HD_k)^⊤(HD_k)$.

# %%
from scipy.linalg import pinv

def MM_MG(f = f,
       gradient_f = grad_f, 
    x_0 = x_0,
      TOLERANCE = TOLERANCE,
         list_values = False):
    
    counter = 0
    start_time = time.time()
    
    D = -gradient_f(x_0)
#     breakpoint()
    u = - 1/(D.T @ (A(x_0) @ D)) * (D.T @ D)
    step = u * D
    x = x_0 + step
    v = []
    
    while True:
        Grad_f_x = gradient_f(x)
        criterion = norm(Grad_f_x)
        if criterion < TOLERANCE:
            temps = time.time() - start_time
            print("{} iterations, gradient norm is {}, elapsed time {:f}".format(counter, criterion,temps))
            if list_values == True:
                return [v, temps]
            else :
                return x

        D = np.vstack((-Grad_f_x, step)).T
        u = -pinv(D.T @ (A(x) @ D)) @ (D.T @ Grad_f_x)
        step = D @ u
        x = x + step
        if list_values == True:
                v.append(f(x))

        counter+=1
        if counter%100 == 0:
            print("{} iteraions, gradient norm is {}, elapsed time {:f}".format(counter, criterion, time.time() - start_time))

# %%
optimum_3MG = MM_MG()
# Out:
# 100 iteraions, gradient norm is 0.27236162450495405, elapsed time 4.328557
# 144 iteraions, gradient norm is 0.008321832056903846, elapsed time 6.171874

# %% [markdown]
# _Remark_: The relative error between the optimums obtained by 3 different algorithms is relatively small and the error between 3MG and MM is much smaller.

# %%
np.max(np.abs(optimum_MM- optimum_3MG))
# Out:
# 2.9771972229419852e-05

# %%
np.max(np.abs(optimum_gd- optimum_3MG))
# Out:
# 0.0001311725707862088

# %% [markdown]
# ### 3.4 Block-coordinate MM quadratic algorithm

# %% [markdown]
# 1. Create a function which gives, as an output, matrix $A_j (x) \in \mathbb{R}^{N_j \times N_j}$ containing only the lines and rows of $A(x)$ with indexes $\mathbb{J}_j$.

# %%
def A_block(x, j, N_j):
    def Delta(u: np.array):
        def dev_psi_over_u(u: np.array):
            return 1 / (DELTA2 * np.sqrt(1 + u**2 / DELTA2))
        return diags(dev_psi_over_u(u))
    Gx = G @ x
    def Ax_u(Gx, u):
        H_block = H[:,j*N_j: j*N_j+N_j]
        G_block = G[:,j*N_j: j*N_j+N_j]
        return H_block.T @ (H_block @ u) + LAMBDA * G_block.T @ (Delta(Gx) @ (G_block @ u))
    matvec = partial(Ax_u, Gx)
    
    return LinearOperator((N_j, N_j), matvec = matvec, rmatvec = matvec)

# %% [markdown]
# 2. Deduce an implementation of a block coordinate MM quadratic algorithm for minimizing $f$. Test it for $N_j = N/K$ with $K \in \{1,2,3,5,6,9\}$.

# %%
from scipy.sparse.linalg import bicg

N_j = int(N/K)

def MM_block(f = f,
    gradient_f = grad_f, 
    x_0 = x_0,
    TOLERANCE = TOLERANCE, 
    K = 1, 
    list_values = False):
    
    N_j = int(N/K)
    x = x_0
    v = []
    counter = 0
    start_time = time.time()
    
    while True and counter<500:
        Grad_f_x = gradient_f(x)
        criterion = norm(Grad_f_x)
        
        if criterion < TOLERANCE:
            temps = time.time() - start_time
            print("K = {}, ran in {} iterations, gradient norm is {:15.14}, elapsed time {:f}".format(K, counter, criterion, temps))
            if list_values == True:
                return [v, temps]
            else :
                return x

        j = counter%K
        A_j = A_block(x, j, N_j)
        search_direction =  -bicg(A_j, Grad_f_x[j*N_j:j*N_j+N_j])[0]
        
        #line search
        search_direction_line_search =  np.zeros(N)
        search_direction_line_search[j*N_j:j*N_j+N_j] = search_direction
        t = line_search(f, x, search_direction_line_search, Grad_f_x, initial_step=2)
        x[j*N_j:j*N_j+N_j] += t*search_direction
        if list_values == True:
                v.append(f(x))
        counter+=1
    
        # print("K = {}, ran in {} iterations, gradient norm is {:15.14}, elapsed time {:f}".format(K, counter, criterion, time.time() - start_time))
        # if counter%100 == 0:
            # print("K = {}, ran in {} iterations, gradient norm is {:15.14}, elapsed time {:f}".format(K, counter, criterion, time.time() - start_time))

# %%
for K in [1,2,3,5,6,9]:
    x_0 = np.zeros(N) 
    optimum_MM_block = MM_block(f, grad_f, x_0, TOLERANCE, K)
# Out:
# K = 1, ran in 39 iterations, gradient norm is 0.0082792199779853, elapsed time 41.913495
# K = 2, ran in 91 iterations, gradient norm is 0.0081907561652613, elapsed time 101.786068
# K = 3, ran in 141 iterations, gradient norm is 0.0066528792422554, elapsed time 117.180070
# K = 5, ran in 247 iterations, gradient norm is 0.0089603094108915, elapsed time 142.243212
# K = 6, ran in 272 iterations, gradient norm is 0.0080656500131019, elapsed time 126.526941
# K = 9, ran in 421 iterations, gradient norm is 0.0082366117613391, elapsed time 155.583495

# %% [markdown]
# These results are not what we were expecting : the block coordinate strategy should have reduced the computation time, which is clearly not the case here. This might be because the function $\texttt{A_block}$ that was implemented is time-consuming (it requires to section matrices).

# %% [markdown]
# ### 3.6 Comparaison of the methods

# %% [markdown]
# 2. We will consider that the convergence is reached when the following stopping criterion is fulfilled :$$
# \Vert \nabla f(x_k)\Vert \leq  \sqrt{N}\times 10 .$$
# What is the required time for each method to achieve this condition? For each method, plot the decrease of $(f(x_k))_{k\in \mathbb{N}}$ versus time until the stopping criterion is satisfied.

# %%
x_0 = np.zeros(N)
values_gd, time_gd = grad_descent(f, grad_f, x_0, TOLERANCE, list_values = True)
values_MM, time_MM = MM(f, grad_f, x_0, TOLERANCE, list_values = True)
values_3MG, time_3MG = MM_MG(f, grad_f, x_0, TOLERANCE, list_values = True)
values_MMblock, time_MMblock = MM_block(f, grad_f, x_0, TOLERANCE, 2, list_values = True)

plt.subplot(2,2,1)
plt.semilogy(values_gd, 'ro')
plt.title('Gradient descent, time = {:6.5}'.format(time_gd))

plt.subplot(2,2,2)
plt.semilogy(values_MM, 'ro')
plt.title('Algorithm MM, time = {:6.5}'.format(time_MM))

plt.subplot(2,2,3)
plt.semilogy(values_3MG, 'ro')
plt.title('Algorithm 3MG, time = {:6.5}'.format(time_3MG))

plt.subplot(2,2,4)
plt.semilogy(values_MMblock, 'ro')
plt.title('Algorithm MM block coordinates, K = 2, time = {:6.5}'.format(time_MMblock))

plt.show()

# %% [markdown]
# The 3MG algorithm achieves by far the best time (4 times faster than the MM algorithm) even though it needs more iterations to reach the criterion.

# %% [markdown]
# 3. The Signal to Noise Ration (SNR) of a restored image $\hat{x}$ is defined as
# $$SNR = 10 \log(\Vert \bar{x} \Vert^2 /\Vert\bar{x} - \hat{x} \Vert^2 )$$
#
# Using the fastest method, search for parameters $\lambda, \delta$ that optimize the SNR. We chose to search on a grid $10 \times 10$ which is not optimal but not too long.

# %%
def SNR(x, x_hat):
    return 10*np.log(x @ x / ((x - x_hat)@ (x - x_hat)))

# %%
x_0 = np.zeros(N)
list_delta = np.linspace(0.005, 0.02, 10)
list_lambda = np.linspace(0.005, 0.1, 10)

SNR_max = 0
i_max, j_max = 0, 0

for i, DELTA in enumerate(list_delta):
    DELTA2 = DELTA**2
    for j, LAMBDA in enumerate(list_lambda):
        L = ( svds(H, k = 1)[1] + (LAMBDA/DELTA2) * svds(G, k = 1)[1] )[0]
        x_hat = MM_MG(f = f, gradient_f = grad_f, x_0 = x_0, TOLERANCE = TOLERANCE)
        SNR_present = SNR(x, x_hat)
        
        if SNR_present > SNR_max:
            SNR_max = SNR_present
            i_min = i
            j_min = j
# Out:
# 100 iteraions, gradient norm is 8.47402268498772, elapsed time 3.368545
# 200 iteraions, gradient norm is 0.26466226939942455, elapsed time 6.475163
# 300 iteraions, gradient norm is 0.012950615765309833, elapsed time 9.586187
# 312 iterations, gradient norm is 0.008911538011339733, elapsed time 9.971554
# 100 iteraions, gradient norm is 1.2697733197390912, elapsed time 3.108131
# 200 iteraions, gradient norm is 0.016402855277148652, elapsed time 6.223323
# 212 iterations, gradient norm is 0.008674986640123391, elapsed time 6.611379
# 100 iteraions, gradient norm is 1.105260707563329, elapsed time 3.147012
# 181 iterations, gradient norm is 0.00875758423281807, elapsed time 5.670136
# 100 iteraions, gradient norm is 0.7890091022187371, elapsed time 3.122069
# 188 iterations, gradient norm is 0.008868087052883812, elapsed time 5.889456
# 100 iteraions, gradient norm is 0.7459241613206011, elapsed time 3.105137
# 198 iterations, gradient norm is 0.008850685865320233, elapsed time 6.160766
# 100 iteraions, gradient norm is 0.9011244202032775, elapsed time 3.134385
# 200 iteraions, gradient norm is 0.014472202986365448, elapsed time 6.243588
# 212 iterations, gradient norm is 0.008990013360981253, elapsed time 6.633915
# 100 iteraions, gradient norm is 1.2396048398052701, elapsed time 3.129488
# 200 iteraions, gradient norm is 0.029878426477520613, elapsed time 6.244093
# 241 iterations, gradient norm is 0.008969621067675796, elapsed time 7.523672
# 100 iteraions, gradient norm is 1.720789158465005, elapsed time 3.124724
# 200 iteraions, gradient norm is 0.03634337347505086, elapsed time 6.227810
# 244 iterations, gradient norm is 0.008931121565287055, elapsed time 7.626273
# 100 iteraions, gradient norm is 2.4445389922756826, elapsed time 3.106128
# 200 iteraions, gradient norm is 0.05743282359802216, elapsed time 6.188016
# 257 iterations, gradient norm is 0.008794312292956416, elapsed time 7.958462
# 100 iteraions, gradient norm is 3.254964424646915, elapsed time 3.098832
# 200 iteraions, gradient norm is 0.09493751506870889, elapsed time 6.216901
# 283 iterations, gradient norm is 0.008972304256749289, elapsed time 8.799582
# 100 iteraions, gradient norm is 10.83455318431668, elapsed time 3.152813
# 200 iteraions, gradient norm is 0.5946775853748721, elapsed time 6.267178
# 300 iteraions, gradient norm is 0.04913276103557356, elapsed time 9.352002
# 366 iterations, gradient norm is 0.008989056574449053, elapsed time 11.394982
# 100 iteraions, gradient norm is 1.763885684957032, elapsed time 3.095953
# 200 iteraions, gradient norm is 0.027044201815115257, elapsed time 6.199137
# 227 iterations, gradient norm is 0.00879217735938087, elapsed time 7.061188
# 100 iteraions, gradient norm is 1.0340908007681229, elapsed time 3.162190
# 195 iterations, gradient norm is 0.008852333866859088, elapsed time 6.148767
# 100 iteraions, gradient norm is 0.7955348501458864, elapsed time 3.129574
# 172 iterations, gradient norm is 0.008726819908754763, elapsed time 5.362891
# 100 iteraions, gradient norm is 0.5669186667947237, elapsed time 3.101746
# 172 iterations, gradient norm is 0.008945059750133325, elapsed time 5.343273
# 100 iteraions, gradient norm is 0.4895107001453558, elapsed time 3.137874
# 177 iterations, gradient norm is 0.00877727259541346, elapsed time 5.526775
# 100 iteraions, gradient norm is 0.5171030231223762, elapsed time 3.110632
# 180 iterations, gradient norm is 0.008775456967965122, elapsed time 5.635671
# 100 iteraions, gradient norm is 0.5271345695585147, elapsed time 3.136928
# 189 iterations, gradient norm is 0.008861839972986226, elapsed time 5.896905
# 100 iteraions, gradient norm is 0.5723568663137956, elapsed time 3.109723
# 200 iteraions, gradient norm is 0.009621411107213653, elapsed time 6.205108
# 201 iterations, gradient norm is 0.008950713368026867, elapsed time 6.244680
# 100 iteraions, gradient norm is 0.7351763074567571, elapsed time 3.107211
# 200 iteraions, gradient norm is 0.01135808675278757, elapsed time 6.205090
# 206 iterations, gradient norm is 0.008786480433965146, elapsed time 6.398806
# 100 iteraions, gradient norm is 15.606886698977465, elapsed time 3.108182
# 200 iteraions, gradient norm is 1.25451792079266, elapsed time 6.200257
# 300 iteraions, gradient norm is 0.12526801700862342, elapsed time 9.276966
# 400 iteraions, gradient norm is 0.012592348338863368, elapsed time 12.357860
# 417 iterations, gradient norm is 0.008219352172441382, elapsed time 12.893431
# 100 iteraions, gradient norm is 2.3710969989919177, elapsed time 3.111106
# 200 iteraions, gradient norm is 0.05108672851325079, elapsed time 6.217283
# 238 iterations, gradient norm is 0.008970366179390904, elapsed time 7.399522
# 100 iteraions, gradient norm is 0.9908989626394143, elapsed time 3.089612
# 200 iteraions, gradient norm is 0.013090104588041433, elapsed time 6.191042
# 206 iterations, gradient norm is 0.00883238901209492, elapsed time 6.383379
# 100 iteraions, gradient norm is 0.9446702643805351, elapsed time 3.108516
# 181 iterations, gradient norm is 0.008905153123349429, elapsed time 5.649535
# 100 iteraions, gradient norm is 0.655443312412302, elapsed time 3.243983
# 165 iterations, gradient norm is 0.008639732138934634, elapsed time 5.261415
# 100 iteraions, gradient norm is 0.47072664072669845, elapsed time 3.121112
# 164 iterations, gradient norm is 0.008391826916372792, elapsed time 5.110173
# 100 iteraions, gradient norm is 0.387695185875702, elapsed time 3.126323
# 164 iterations, gradient norm is 0.008933395454809387, elapsed time 5.115795
# 100 iteraions, gradient norm is 0.3670492678805298, elapsed time 3.090247
# 165 iterations, gradient norm is 0.008916691598994402, elapsed time 5.143413
# 100 iteraions, gradient norm is 0.3633359385709051, elapsed time 3.145717
# 165 iterations, gradient norm is 0.008936408312173403, elapsed time 5.164297
# 100 iteraions, gradient norm is 0.3718122029526234, elapsed time 3.092505
# 173 iterations, gradient norm is 0.008805065854466885, elapsed time 5.386850
# 100 iteraions, gradient norm is 17.688769260178102, elapsed time 3.106242
# 200 iteraions, gradient norm is 2.3082424565034025, elapsed time 6.227440
# 300 iteraions, gradient norm is 0.34143663312305267, elapsed time 9.341132
# 400 iteraions, gradient norm is 0.046803164432934814, elapsed time 12.416527
# 483 iterations, gradient norm is 0.008797435595312118, elapsed time 14.981327
# 100 iteraions, gradient norm is 3.2546319596976394, elapsed time 3.101222
# 200 iteraions, gradient norm is 0.05929887440837262, elapsed time 6.212986
# 243 iterations, gradient norm is 0.00881097446420737, elapsed time 7.545707
# 100 iteraions, gradient norm is 1.2680227302528635, elapsed time 3.090492
# 200 iteraions, gradient norm is 0.009102228888759046, elapsed time 6.203665
# 200 iterations, gradient norm is 0.008278474971398397, elapsed time 6.211331
# 100 iteraions, gradient norm is 0.9072365523562951, elapsed time 3.124703
# 195 iterations, gradient norm is 0.008892275916496054, elapsed time 6.077090
# 100 iteraions, gradient norm is 0.8139067319360864, elapsed time 3.103060
# 173 iterations, gradient norm is 0.008660095762126596, elapsed time 5.358194
# 100 iteraions, gradient norm is 0.5528733790622384, elapsed time 3.104306
# 160 iterations, gradient norm is 0.008803035795537352, elapsed time 4.957431
# 100 iteraions, gradient norm is 0.43091942361008856, elapsed time 3.123497
# 158 iterations, gradient norm is 0.008937038566757125, elapsed time 4.988692
# 100 iteraions, gradient norm is 0.33185320585806505, elapsed time 3.127546
# 157 iterations, gradient norm is 0.008723877071311942, elapsed time 4.892243
# 100 iteraions, gradient norm is 0.2987711463590128, elapsed time 3.109675
# 157 iterations, gradient norm is 0.008502534239031795, elapsed time 4.886431
# 100 iteraions, gradient norm is 0.2730063399855083, elapsed time 3.099946
# 155 iterations, gradient norm is 0.008537123495228503, elapsed time 4.820967
# 100 iteraions, gradient norm is 25.85542152242299, elapsed time 3.105898
# 200 iteraions, gradient norm is 3.0636856187280976, elapsed time 6.186001
# 300 iteraions, gradient norm is 0.6587310528564181, elapsed time 9.260153
# 400 iteraions, gradient norm is 0.1297382375980499, elapsed time 12.358971
# 500 iteraions, gradient norm is 0.02441783749826621, elapsed time 15.442978
# 549 iterations, gradient norm is 0.008956473375234902, elapsed time 16.960367
# 100 iteraions, gradient norm is 3.8689201994675204, elapsed time 3.092208
# 200 iteraions, gradient norm is 0.061491746385865256, elapsed time 6.181765
# 255 iterations, gradient norm is 0.008380544053032218, elapsed time 7.880837
# 100 iteraions, gradient norm is 1.6177154335665351, elapsed time 3.097529
# 200 iteraions, gradient norm is 0.026280452074663882, elapsed time 6.178068
# 223 iterations, gradient norm is 0.00891339208041411, elapsed time 6.894688
# 100 iteraions, gradient norm is 0.8625938255295026, elapsed time 3.095268
# 200 iteraions, gradient norm is 0.010551953045301782, elapsed time 6.167145
# 202 iterations, gradient norm is 0.008527172690750769, elapsed time 6.243892
# 100 iteraions, gradient norm is 0.8796818699985274, elapsed time 3.134886
# 184 iterations, gradient norm is 0.008340068129248885, elapsed time 5.756728
# 100 iteraions, gradient norm is 0.7265111252774044, elapsed time 3.111391
# 167 iterations, gradient norm is 0.008285557342930525, elapsed time 5.176702
# 100 iteraions, gradient norm is 0.48558249716312996, elapsed time 3.117250
# 156 iterations, gradient norm is 0.008936244652337458, elapsed time 4.860707
# 100 iteraions, gradient norm is 0.3833641497504314, elapsed time 3.110699
# 155 iterations, gradient norm is 0.008878045805972366, elapsed time 4.815531
# 100 iteraions, gradient norm is 0.30862612838790104, elapsed time 3.104008
# 153 iterations, gradient norm is 0.008583309138101245, elapsed time 4.745694
# 100 iteraions, gradient norm is 0.26753616388429113, elapsed time 3.111812
# 151 iterations, gradient norm is 0.008714362413879767, elapsed time 4.711884
# 100 iteraions, gradient norm is 29.048617319156254, elapsed time 3.108845
# 200 iteraions, gradient norm is 3.969792399341537, elapsed time 6.207098
# 300 iteraions, gradient norm is 0.9357819040991895, elapsed time 9.291648
# 400 iteraions, gradient norm is 0.20861866066988868, elapsed time 12.405082
# 500 iteraions, gradient norm is 0.05628071067980925, elapsed time 15.482438
# 600 iteraions, gradient norm is 0.012313046751808113, elapsed time 18.571011
# 616 iterations, gradient norm is 0.008952737282245557, elapsed time 19.077683
# 100 iteraions, gradient norm is 5.176490908279136, elapsed time 3.109748
# 200 iteraions, gradient norm is 0.09690675379899692, elapsed time 6.213281
# 268 iterations, gradient norm is 0.008734383249217425, elapsed time 8.333943
# 100 iteraions, gradient norm is 2.143919813398737, elapsed time 3.096779
# 200 iteraions, gradient norm is 0.03509983194735558, elapsed time 6.182743
# 228 iterations, gradient norm is 0.008938450649211525, elapsed time 7.060562
# 100 iteraions, gradient norm is 1.0848816818313152, elapsed time 3.111734
# 184 iterations, gradient norm is 0.008660823493380184, elapsed time 5.728506
# 100 iteraions, gradient norm is 0.8198583786562389, elapsed time 3.106005
# 193 iterations, gradient norm is 0.008539830326362479, elapsed time 5.972694
# 100 iteraions, gradient norm is 0.7961518790689981, elapsed time 3.128154
# 175 iterations, gradient norm is 0.008879588880193247, elapsed time 5.458853
# 100 iteraions, gradient norm is 0.6351304075859122, elapsed time 3.108959
# 162 iterations, gradient norm is 0.007946421889265672, elapsed time 5.027928
# 100 iteraions, gradient norm is 0.43145293278205965, elapsed time 3.102724
# 154 iterations, gradient norm is 0.008415137327043165, elapsed time 4.780715
# 100 iteraions, gradient norm is 0.3581395590974503, elapsed time 3.109719
# 152 iterations, gradient norm is 0.00897706545821825, elapsed time 4.717005
# 100 iteraions, gradient norm is 0.2854316804119978, elapsed time 3.132498
# 150 iterations, gradient norm is 0.008453780005067232, elapsed time 4.683626
# 100 iteraions, gradient norm is 35.45817834551024, elapsed time 3.106583
# 200 iteraions, gradient norm is 4.975649334876, elapsed time 6.268969
# 300 iteraions, gradient norm is 1.2164474392371096, elapsed time 9.347095
# 400 iteraions, gradient norm is 0.33393382960223333, elapsed time 12.423552
# 500 iteraions, gradient norm is 0.09858552785673748, elapsed time 15.503517
# 600 iteraions, gradient norm is 0.026016674975106065, elapsed time 18.615558
# 671 iterations, gradient norm is 0.008848946316161677, elapsed time 20.834302
# 100 iteraions, gradient norm is 5.516310509369153, elapsed time 3.095595
# 200 iteraions, gradient norm is 0.12237485435954396, elapsed time 6.192261
# 271 iterations, gradient norm is 0.00824060382436295, elapsed time 8.392284
# 100 iteraions, gradient norm is 2.537096549285521, elapsed time 3.107013
# 200 iteraions, gradient norm is 0.04162545176881602, elapsed time 6.205698
# 232 iterations, gradient norm is 0.008507738080133885, elapsed time 7.202546
# 100 iteraions, gradient norm is 1.2436484742853549, elapsed time 3.106310
# 200 iteraions, gradient norm is 0.014477810444674916, elapsed time 6.195674
# 210 iterations, gradient norm is 0.008842218292917894, elapsed time 6.515974
# 100 iteraions, gradient norm is 0.8083019978246675, elapsed time 3.101015
# 198 iterations, gradient norm is 0.007822220892124282, elapsed time 6.124806
# 100 iteraions, gradient norm is 0.8082332250376228, elapsed time 3.119455
# 184 iterations, gradient norm is 0.008551973274366, elapsed time 5.721294
# 100 iteraions, gradient norm is 0.7133057287942172, elapsed time 3.107498
# 169 iterations, gradient norm is 0.008663649904573988, elapsed time 5.245532
# 100 iteraions, gradient norm is 0.5463172499583185, elapsed time 3.102459
# 158 iterations, gradient norm is 0.0075853194776907586, elapsed time 4.893642
# 100 iteraions, gradient norm is 0.3928371316967246, elapsed time 3.113219
# 152 iterations, gradient norm is 0.00860584597816073, elapsed time 4.754897
# 100 iteraions, gradient norm is 0.33280220120684306, elapsed time 3.124473
# 150 iterations, gradient norm is 0.008589226447364137, elapsed time 4.670663
# 100 iteraions, gradient norm is 36.77269047964566, elapsed time 3.109957
# 200 iteraions, gradient norm is 6.1343372573625805, elapsed time 6.188966
# 300 iteraions, gradient norm is 1.4302172228141556, elapsed time 9.269072
# 400 iteraions, gradient norm is 0.4058876998199845, elapsed time 12.357192
# 500 iteraions, gradient norm is 0.14684435225045175, elapsed time 15.430696
# 600 iteraions, gradient norm is 0.04129710087739763, elapsed time 18.511972
# 700 iteraions, gradient norm is 0.009670097824107477, elapsed time 21.596086
# 705 iterations, gradient norm is 0.008783754460129495, elapsed time 21.758001
# 100 iteraions, gradient norm is 6.801271854219327, elapsed time 3.117612
# 200 iteraions, gradient norm is 0.2097958337470687, elapsed time 6.194572
# 299 iterations, gradient norm is 0.008671752522673187, elapsed time 9.497872
# 100 iteraions, gradient norm is 2.826351556127873, elapsed time 3.477263
# 200 iteraions, gradient norm is 0.03571776154477464, elapsed time 6.567855
# 233 iterations, gradient norm is 0.008998391549998534, elapsed time 7.616239
# 100 iteraions, gradient norm is 1.5883893163437095, elapsed time 3.107102
# 200 iteraions, gradient norm is 0.021370074021779387, elapsed time 6.193444
# 218 iterations, gradient norm is 0.008292032880794383, elapsed time 6.760182
# 100 iteraions, gradient norm is 0.9301808907653946, elapsed time 3.316835
# 190 iterations, gradient norm is 0.008829428259615862, elapsed time 6.110970
# 100 iteraions, gradient norm is 0.753691533337143, elapsed time 4.282828
# 189 iterations, gradient norm is 0.00833466944440255, elapsed time 9.126638
# 100 iteraions, gradient norm is 0.7809886679654402, elapsed time 3.981539
# 176 iterations, gradient norm is 0.008701286008616213, elapsed time 6.541761
# 100 iteraions, gradient norm is 0.6469516345674332, elapsed time 3.946719
# 164 iterations, gradient norm is 0.008667270638413825, elapsed time 6.270905
# 100 iteraions, gradient norm is 0.4747882413014576, elapsed time 3.190705
# 153 iterations, gradient norm is 0.00821374560252038, elapsed time 4.914678
# 100 iteraions, gradient norm is 0.3575458313060857, elapsed time 3.636217
# 149 iterations, gradient norm is 0.008875637364580156, elapsed time 5.214386
# 100 iteraions, gradient norm is 35.43997834540607, elapsed time 3.541862
# 200 iteraions, gradient norm is 6.680559586779529, elapsed time 6.774309
# 300 iteraions, gradient norm is 2.019066399038476, elapsed time 9.883789
# 400 iteraions, gradient norm is 0.5249306191065328, elapsed time 13.073217
# 500 iteraions, gradient norm is 0.16822358063383464, elapsed time 16.418053
# 600 iteraions, gradient norm is 0.05191701281446814, elapsed time 19.854605
# 700 iteraions, gradient norm is 0.015766404707287573, elapsed time 22.973481
# 738 iterations, gradient norm is 0.008728828569912271, elapsed time 24.376933
# 100 iteraions, gradient norm is 9.151421796316585, elapsed time 3.155404
# 200 iteraions, gradient norm is 0.3327617049589654, elapsed time 6.460057
# 300 iteraions, gradient norm is 0.01536096085591532, elapsed time 9.565473
# 320 iterations, gradient norm is 0.008736902548835933, elapsed time 10.372946
# 100 iteraions, gradient norm is 3.299987717300486, elapsed time 3.186544
# 200 iteraions, gradient norm is 0.036970135632881033, elapsed time 6.502202
# 233 iterations, gradient norm is 0.008924506957552349, elapsed time 7.538517
# 100 iteraions, gradient norm is 1.8138607755064076, elapsed time 3.784685
# 200 iteraions, gradient norm is 0.025200705090232575, elapsed time 7.152277
# 222 iterations, gradient norm is 0.008676575111984811, elapsed time 7.844145
# 100 iteraions, gradient norm is 1.0587316840746979, elapsed time 3.198585
# 200 iteraions, gradient norm is 0.010246990813001915, elapsed time 6.460230
# 200 iterations, gradient norm is 0.008771366100957348, elapsed time 6.470860
# 100 iteraions, gradient norm is 0.8045208935390274, elapsed time 3.467572
# 193 iterations, gradient norm is 0.008232087450852086, elapsed time 6.852243
# 100 iteraions, gradient norm is 0.760778209546406, elapsed time 3.142000
# 183 iterations, gradient norm is 0.008054114238314562, elapsed time 5.755421
# 100 iteraions, gradient norm is 0.7401022560726281, elapsed time 3.142780
# 171 iterations, gradient norm is 0.008573104798555636, elapsed time 5.339315
# 100 iteraions, gradient norm is 0.5880562746643766, elapsed time 3.139173
# 160 iterations, gradient norm is 0.008541608064852331, elapsed time 4.996045
# 100 iteraions, gradient norm is 0.42142031216555487, elapsed time 3.290813
# 149 iterations, gradient norm is 0.00886871290442396, elapsed time 4.834971
# 100 iteraions, gradient norm is 43.551897120260755, elapsed time 3.326400
# 200 iteraions, gradient norm is 7.190531431276275, elapsed time 6.450830
# 300 iteraions, gradient norm is 2.627785503119954, elapsed time 9.624677
# 400 iteraions, gradient norm is 0.6687493102950985, elapsed time 12.725723
# 500 iteraions, gradient norm is 0.208292512835006, elapsed time 15.855708
# 600 iteraions, gradient norm is 0.06604903722834086, elapsed time 18.945630
# 700 iteraions, gradient norm is 0.018762757201794125, elapsed time 22.041366
# 765 iterations, gradient norm is 0.00896113456261063, elapsed time 24.083012
# 100 iteraions, gradient norm is 9.331483107649577, elapsed time 3.147558
# 200 iteraions, gradient norm is 0.4875570594993373, elapsed time 6.349569
# 300 iteraions, gradient norm is 0.02303488347596597, elapsed time 9.458787
# 332 iterations, gradient norm is 0.008920663677343595, elapsed time 10.474992
# 100 iteraions, gradient norm is 4.223137613355694, elapsed time 3.143735
# 200 iteraions, gradient norm is 0.04650682641650687, elapsed time 6.258478
# 239 iterations, gradient norm is 0.008469393973325174, elapsed time 7.505514
# 100 iteraions, gradient norm is 2.0029366094216003, elapsed time 3.141679
# 200 iteraions, gradient norm is 0.025913974295737267, elapsed time 6.270710
# 222 iterations, gradient norm is 0.008513377179110587, elapsed time 6.965832
# 100 iteraions, gradient norm is 1.1627669746017708, elapsed time 3.149347
# 200 iteraions, gradient norm is 0.014988414250785616, elapsed time 6.284933
# 207 iterations, gradient norm is 0.008918429425073817, elapsed time 6.512981
# 100 iteraions, gradient norm is 0.7994172962752877, elapsed time 3.137362
# 190 iterations, gradient norm is 0.008720146627116664, elapsed time 6.156917
# 100 iteraions, gradient norm is 0.7550046889758173, elapsed time 3.150354
# 186 iterations, gradient norm is 0.008973010857033174, elapsed time 5.891739
# 100 iteraions, gradient norm is 0.7692460836814715, elapsed time 3.542241
# 176 iterations, gradient norm is 0.008523094788459622, elapsed time 6.250466
# 100 iteraions, gradient norm is 0.7036902541975119, elapsed time 3.446162
# 165 iterations, gradient norm is 0.008837424148149167, elapsed time 5.641464
# 100 iteraions, gradient norm is 0.5405308785733758, elapsed time 3.402874
# 156 iterations, gradient norm is 0.008551214864700183, elapsed time 5.342426

# %%
print('Best SNR achieved is {} with lambda = {}, delta = {}'.format(SNR_max, list_lambda[j_max],list_delta[i_max]) )
# Out:
# Best SNR achieved is 43.44652062289231 with lambda = 0.005, delta = 0.005
